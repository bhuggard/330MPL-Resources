# %% [markdown]
# # SI370 Day 6 - Describing Data and Visualization I

# %%
NOTEBOOK_VERSION="2.2"

# %%
UNIQNAME = "bhuggard"

# %% [markdown]
# ## NOTE: This notebook requires you to have Seaborn version 0.11.0 or newer.

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.11.2

# %%
# if your version is less than 0.11.0, uncomment the following line and run this cell
#pip install --upgrade seaborn

# %% [markdown]
# ## Exercise 1
# The sample.csv file, included with today's lab, contains 9 variables (v0 through v9) that contain
# measures drawn from different distributions.
# Your task is to use the investigative techniques covered in the pre-recorded lecture to determine
# what type of distribution the sample is drawn from.
#
# You should first load the CSV file into a DataFrame, then look at various aspects of **each** variable.
# Your responses should consist of code cells, as well as markdown cells that state something like:
# > Variable v99 appears to be drawn from a uniform distribution with mean X and standard deviation Y.
# > A histogram of the data appears to be...
# > The QQ plot shows....

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
df = pd.read_csv('sample.csv')

# %%
#loading multiple plots function

def multiplePlots( series ):
    
    fig, axs = plt.subplots(2,2)
    plt.tight_layout(pad=0.4, w_pad=4, h_pad=1.0)

    # Histogram
    sns.histplot(series, ax=axs[0,0])
    
    # Lag plot
    lag = series.copy()
    lag = np.array(lag[:-1])
    current = series[1:]
    ax = sns.regplot(x=current,y=lag,fit_reg=False, ax=axs[0,1])
    ax.set_ylabel("y_i-1")
    ax.set_xlabel("y_i")
    
    # QQ plot
    qntls, xr = stats.probplot(series, fit=False)
    sns.regplot(x=xr,y=qntls, ax=axs[1,0])
    
    # Run sequence
    ax = sns.regplot(np.arange(len(series)),series, ax=axs[1,1])
    ax.set_ylabel("val")
    ax.set_xlabel("i")

# %%
df.describe()
# Out:
#        Unnamed: 0          v0          v1          v2          v3          v4  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean   249.500000    0.048769    1.025355   -4.530455    1.604000   30.768000
# std    144.481833    1.168859  104.943593  101.424790    2.766675   20.301687
# min      0.000000   -1.998116 -188.691985 -376.499646    1.000000  -34.000000
# 25%    124.750000   -0.918946  -78.735102  -61.984783    1.000000   17.000000
# 50%    249.500000    0.166880  -16.207729   13.614648    1.000000   31.000000
# 75%    374.250000    1.054630   61.301734   75.711610    1.000000   43.000000
# max    499.000000    1.996645  385.891667  151.545441   38.000000   91.000000
#
#                v5          v6          v7          v8
# count  500.000000  500.000000  500.000000  500.000000
# mean     2.082000  148.182000   -0.390372  198.792000
# std      1.341221   19.523093   22.506730   34.577506
# ...

# %%
multiplePlots(df['v0'])
# Out:
# C:\Users\bhugg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['v0'].describe()
# Out:
# count    500.000000
# mean       0.048769
# std        1.168859
# min       -1.998116
# 25%       -0.918946
# 50%        0.166880
# 75%        1.054630
# max        1.996645
# Name: v0, dtype: float64

# %% [markdown]
# Variable v0 appears to be drawn from a uniform distribution with mean 0.0488 and standard deviation 1.17.
# A histogram of the data appears to be Uniformly stacked with the point just below 0 being underrepresented. The QQ plot shows

# %%
multiplePlots(df['v1'])
# Out:
# C:\Users\bhugg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['v1'].describe()
# Out:
# count    500.000000
# mean       1.025355
# std      104.943593
# min     -188.691985
# 25%      -78.735102
# 50%      -16.207729
# 75%       61.301734
# max      385.891667
# Name: v1, dtype: float64

# %% [markdown]
# Variable v1 appears to be drawn from a right skewed distribution with mean 1.025 and standard deviation 104.94.
# A histogram of the data appears to be skewed right with some heavy outliers by 400. The QQ plot shows

# %%
multiplePlots(df['v2'])
# Out:
# C:\Users\bhugg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['v2'].describe()
# Out:
# count    500.000000
# mean      -4.530455
# std      101.424790
# min     -376.499646
# 25%      -61.984783
# 50%       13.614648
# 75%       75.711610
# max      151.545441
# Name: v2, dtype: float64

# %% [markdown]
# Variable v2 appears to be drawn from a skewed left distribution with mean -4.53 and standard deviation 101.42.
# A histogram of the data appears to be skewed left with the points just above -400 being outliers. The QQ plot shows

# %%
multiplePlots(df['v3'])
# Out:
# C:\Users\bhugg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['v3'].describe()
# Out:
# count    500.000000
# mean       1.604000
# std        2.766675
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max       38.000000
# Name: v3, dtype: float64

# %% [markdown]
# Variable v3 is interesting and unusual. Anything below the 75th percentile is one, with a few outliers up around 38.

# %%
multiplePlots(df['v4'])
# Out:
# C:\Users\bhugg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['v4'].describe()
# Out:
# count    500.000000
# mean      30.768000
# std       20.301687
# min      -34.000000
# 25%       17.000000
# 50%       31.000000
# 75%       43.000000
# max       91.000000
# Name: v4, dtype: float64

# %% [markdown]
# Variable v4 appears to be drawn from a normal distribution with mean 30.77 and standard deviation 20.30.
# A histogram of the data appears to be normally distributed with no clear issues or mode. The QQ plot shows

# %%
multiplePlots(df['v5'])
# Out:
# C:\Users\bhugg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['v5'].describe()
# Out:
# count    500.000000
# mean       2.082000
# std        1.341221
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        6.000000
# Name: v5, dtype: float64

# %% [markdown]
# Variable v5 is unusual. We can see the histogram, QQ plot, Lag sequence, and run sequence are all staggered with mean 2.08 and standard deviaiton 1.34. The IQR which may be useful given the multi-modal nature is 2.

# %%
multiplePlots(df['v6'])
# Out:
# C:\Users\bhugg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['v6'].describe()
# Out:
# count    500.000000
# mean     148.182000
# std       19.523093
# min       94.000000
# 25%      134.000000
# 50%      147.000000
# 75%      161.000000
# max      216.000000
# Name: v6, dtype: float64

# %% [markdown]
# Variable v6 appears to be drawn from a normal distribution with mean 148.18 and standard deviation 19.52.
# A histogram of the data appears to be normally distributed with no clear issues and a mode around 145. The QQ plot shows

# %%
multiplePlots(df['v7'])
# Out:
# C:\Users\bhugg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['v7'].describe()
# Out:
# count    500.000000
# mean      -0.390372
# std       22.506730
# min      -47.573673
# 25%      -21.067972
# 50%       -1.304978
# 75%       20.397352
# max       42.922994
# Name: v7, dtype: float64

# %% [markdown]
# Variable v7 appears to be drawn from a bimodal distribution with mean -0.39 and standard deviation 22.506.
# A histogram of the data appears to be bimodally distributed with no clear issues and a modes around -15 and 20. The QQ plot shows we are farther from the center at both of these points

# %%
multiplePlots(df['v8'])
# Out:
# C:\Users\bhugg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['v8'].describe()
# Out:
# count    500.000000
# mean     198.792000
# std       34.577506
# min      106.000000
# 25%      174.750000
# 50%      197.000000
# 75%      225.150000
# max      286.800000
# Name: v8, dtype: float64

# %% [markdown]
# Variable v8 appears to be drawn from a normal distribution with mean 198.79 and standard deviation 34.58.
# A histogram of the data appears to be normally distributed with no clear issues and a mode around 145. The QQ plot shows we vary from the center accordingly with our observations.

# %% [markdown]
# ## Exercise 2
#
# Let's take a look at a carefully curated COVID-19 data set.  The full site is available at  https://covid19datahub.io. A description of the dataset can be found at https://covid19datahub.io/articles/doc/data.html and a description of the Python API can be found at https://covid19datahub.io/articles/api/python.html.

# %%
pip install covid19dh
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from covid19dh import covid19
covid_all_countries, src = covid19(level=1)
# Out:
# We have invested a lot of time and effort in creating COVID-19 Data Hub, please cite the following when using it:
#
# 	Guidotti, E., Ardia, D., (2020), "COVID-19 Data Hub", Journal of Open Source Software 5(51):2376, doi: 10.21105/joss.02376.
#
# A BibTeX entry for LaTeX users is
#
# 	@Article{,
# 		title = {COVID-19 Data Hub},
# 		year = {2020},
# 		doi = {10.21105/joss.02376},
# 		author = {Emanuele Guidotti and David Ardia},
# 		journal = {Journal of Open Source Software},
# 		volume = {5},
# 		number = {51},
# 		pages = {2376},
# 	}
#
# To hide this message use 'verbose = False'.

# %%
covid_all_countries.shape
# Out:
# (219399, 47)

# %%
covid_all_countries.columns
# Out:
# Index(['id', 'date', 'confirmed', 'deaths', 'recovered', 'tests', 'vaccines',
#        'people_vaccinated', 'people_fully_vaccinated', 'hosp', 'icu', 'vent',
#        'school_closing', 'workplace_closing', 'cancel_events',
#        'gatherings_restrictions', 'transport_closing',
#        'stay_home_restrictions', 'internal_movement_restrictions',
#        'international_movement_restrictions', 'information_campaigns',
#        'testing_policy', 'contact_tracing', 'facial_coverings',
#        'vaccination_policy', 'elderly_people_protection',
#        'government_response_index', 'stringency_index',
#        'containment_health_index', 'economic_support_index',
#        'administrative_area_level', 'administrative_area_level_1',
#        'administrative_area_level_2', 'administrative_area_level_3',
#        'latitude', 'longitude', 'population', 'iso_alpha_3', 'iso_alpha_2',
#        'iso_numeric', 'iso_currency', 'key_local', 'key_google_mobility',
# ...

# %%
covid_all_countries.iloc[0]
# Out:
# id                                                0094b645
# date                                   2020-01-22 00:00:00
# confirmed                                              NaN
# deaths                                                 NaN
# recovered                                              NaN
# tests                                                  NaN
# vaccines                                               NaN
# people_vaccinated                                      NaN
# people_fully_vaccinated                                NaN
# hosp                                                   NaN
# icu                                                    NaN
# vent                                                   NaN
# school_closing                                         NaN
# workplace_closing                                      NaN
# cancel_events                                          NaN
# gatherings_restrictions                                NaN
# ...

# %%
covid_usa = covid_all_countries.query('administrative_area_level_1 == "United States"')
# alternatively, we could call covid() again with "USA" as a parameter

# %%
covid_usa.shape
# Out:
# (968, 47)

# %%
covid_usa.tail()
# Out:
#              id       date   confirmed     deaths  recovered  tests  vaccines  \
# 87720  59a13ceb 2022-09-10  95006059.0  1046145.0        NaN    NaN       NaN
# 87721  59a13ceb 2022-09-11  95017523.0  1046164.0        NaN    NaN       NaN
# 87722  59a13ceb 2022-09-12  95105036.0  1046733.0        NaN    NaN       NaN
# 87723  59a13ceb 2022-09-13  95166678.0  1047255.0        NaN    NaN       NaN
# 87724  59a13ceb 2022-09-14  95282080.0  1048238.0        NaN    NaN       NaN
#
#        people_vaccinated  people_fully_vaccinated     hosp  ...  iso_alpha_3  \
# 87720                NaN                      NaN  27917.0  ...          USA
# 87721                NaN                      NaN  27960.0  ...          USA
# 87722                NaN                      NaN  28252.0  ...          USA
# 87723                NaN                      NaN      NaN  ...          USA
# 87724                NaN                      NaN      NaN  ...          USA
#
# ...

# %% [markdown]
# ## Exercise 2a
#
# Use a copy of the covid_usa DataFrame and the pd.Series.diff() function to create a new column "daily_tests" that represents the number of tests since the previous day.  Repeat this for "confirmed", and "recovered" to created the columns "daily_confirmed" and "daily_recovered".

# %%
copy = covid_usa.copy()

copy['daily_tests'] = copy['tests'].diff()
copy['daily_confirmed'] = copy['confirmed'].diff()
copy['daily_recovered'] = copy['recovered'].diff()

# %% [markdown]
# ## Exercise 2b
#
# Based on your copy of the covid_usa DataFrame, what are the median values for the number of daily tests, the number of daily confirmed cases, and the number of daily recoveries?

# %%
copy['daily_tests'].median()
# Out:
# 1011561.0

# %%
copy['daily_confirmed'].median()
# Out:
# 57805.0

# %%
copy['daily_recovered'].median()
# Out:
# nan

# %% [markdown]
# Insert your interpretation here.

# %% [markdown]
# ## Exercise 2c
#
# Using the copy of the covid_usa DataFrame, create a histogram showing the distribution of daily_tests.  Repeat this for daily_confirmed and daily_recovered.
#
# Please note that, as of Seaborn version 0.11.0, you can use `sns.histplot()` instead of `sns.distplot()`

# %%
sns.histplot(copy['daily_tests'])
# Out:
# <AxesSubplot:xlabel='daily_tests', ylabel='Count'>

# %%
sns.histplot(copy['daily_confirmed'])
# Out:
# <AxesSubplot:xlabel='daily_confirmed', ylabel='Count'>

# %%
sns.histplot(copy['daily_recovered'])
# Out:
# <AxesSubplot:xlabel='daily_recovered', ylabel='Count'>

# %% [markdown]
# ## Exercise 2d
#
# What do you think the underlying distributions are for daily_tests, daily_confirmed and daily_recovered?

# %% [markdown]
# Tests are skewed left, confirmed match the skew left, recovered seems to be broken.

# %% [markdown]
# ## Stretch exercises
#
# ### Stretch exercise 3a
#
# In case you finish early, feel free to try the following exercises.
#
# The covid19() function takes an optional parameter of "level", which specifies the granularity of the dataset.  Setting level=2 provides, in the case of the United States, state-level data; setting level=3 provides city-level data.
#
# Show the distribution of daily confirmed cases for the state of Michigan.

# %%
# insert your code here

# %% [markdown]
# ### Stretch exercise 3b
#
# You'll notice there are additional variables in the data set that are grouped under the
# heading "Policy measures" (https://covid19datahub.io/articles/doc/data.html).  Explore
# how the distributions of confirmed cases and recoveries change with different levels
# of policy measures.
